# %% [markdown]
# # <div style="text-align: center"> Logistic Regression</div>
# ![images.jpg](attachment:images.jpg)

# %% [markdown]
# # What is logistic regression?

# %% [markdown]
# <div style="text-align: justify"> Logistic regression is the appropriate regression analysis to conduct when the dependent variable is dichotomous (binary).  Like all regression analyses, the logistic regression is a predictive analysis.  Logistic regression is used to describe data and to explain the relationship between one dependent binary variable and one or more nominal, ordinal, interval or ratio-level independent variables. </div>

# %% [markdown]
# **The goal of this tutorial is to solve a simple classification problem using Logistic Regression.**

# %% [markdown]
# # Linear Regression versus Logistic Regression

# %% [markdown]
# <div style='text-align:justify'>Linear Regression can be used to predict something like homeprices or weather and in all this examples the prediction value is **continues**.</br>
# There are other type of problems such as Email spam, election. Inn this case the prediction value is **categorical**, because the answer in Email spam is yes/no or in election the answer is one of the person. Hence, the second type of problems is called classification problem.</div>

# %% [markdown]
# ![Regression_vs_Classification.png](attachment:Regression_vs_Classification.png)

# %% [markdown]
# **Logistic regression is one of the techniques used for classification.**

# %% [markdown]
# There are two types of classification problems:
# 1. Binary classification (Yes/No)
# 2. Multiclass Classification (You have more than two categories)

# %% [markdown]
# ![classification_types.png](attachment:classification_types.png)

# %% [markdown]
# <h2 style="color:green" align="justify">Predicting if a person would buy life insurnace based on his age using logistic regression</h2>

# %% [markdown]
# ![example.png](attachment:example.png)

# %% [markdown]
# Above is a binary logistic regression problem as there are only two possible outcomes (i.e. if person buys insurance or he/she doesn't).

# %% [markdown]
# ## Predict with Linear Regression
# ![Linear_Regression_ok.png](attachment:Linear_Regression_ok.png)

# %% [markdown]
# ## Predict with Logistic Regression
# ![logistic_line.png](attachment:logistic_line.png)

# %% [markdown]
# ![sigmoid_function.png](attachment:sigmoid_function.png)

# %% [markdown]
# z = m$*$x + b
# ![compare_linear_logistic_regression.png](attachment:compare_linear_logistic_regression.png)

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("D:/Data_Science/My Github/Machine-Learning-with-Python/7. logistic_regression/Example/insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age,df.bought_insurance,marker='+',color='red')

# %%
df.shape
# Out:
# (27, 2)

# %%
from sklearn.model_selection import train_test_split

# %%
# Use 90% for train_size
X_train, X_test, y_train, y_test = train_test_split(df[['age']],df.bought_insurance,train_size=0.9)

# %%
X_test
# Out:
#     age
# 9    61
# 24   50
# 12   27

# %%
X_train
# Out:
#     age
# 18   19
# 21   26
# 5    56
# 4    46
# 22   40
# 23   45
# 10   18
# 15   55
# 8    62
# 1    25
# 19   18
# 17   58
# 2    47
# 20   21
# 16   25
# 6    55
# 26   23
# 13   29
# 3    52
# 25   54
# 14   49
# 0    22
# 11   28
# 7    60

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
X_test
# Out:
#     age
# 9    61
# 24   50
# 12   27

# %%
model.predict(X_test)
# Out:
# array([1, 1, 0], dtype=int64)

# %% [markdown]
# [1,1,0] for age [61,50,27] seems true the old people buy the insurance(i.e. 1) & vice versa

# %%
# measure the accuracy of your model
model.score(X_test,y_test)
# Out:
# 1.0

# %% [markdown]
# which means our model is perfect and this is because out data size is small (only 27 samples)

# %%
# Predict a probability
model.predict_proba(X_test)
# Out:
# array([[0.05938775, 0.94061225],
#        [0.20064434, 0.79935566],
#        [0.81810182, 0.18189818]])

# %% [markdown]
# It shows the probability of X_test being in one class versus the other. The first class if the customer will not buy the insurance.

# %% [markdown]
# ## Predict the probebility of age 16?

# %%
model.predict([[16]])
# Out:
# array([0], dtype=int64)

# %% [markdown]
# So 16 not buy the insurance

# %% [markdown]
# <h2 style="color:purple">Exercise</h2>
#
# Download employee retention dataset from here: https://www.kaggle.com/giripujar/hr-analytics.
# 1. Now do some exploratory data analysis to figure out which variables have direct and clear impact on employee retention (i.e. whether they leave the company or continue to work)
# 2. Plot bar charts showing impact of employee salaries on retention
# 3. Plot bar charts showing corelation between department and employee retention
# 4. Now build logistic regression model using variables that were narrowed down in step 1
# 5. Measure the accuracy of the model

# %% [markdown]
# |  Date |  Author |
# |-------|---------|
# | 2021-09-02    |   <font color=blue>**Ehsan Zia**</font>  |
