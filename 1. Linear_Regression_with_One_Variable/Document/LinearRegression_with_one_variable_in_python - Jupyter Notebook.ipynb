# %% [markdown]
# # <div style="text-align: center"> Linear Regression with one variable in Python </div>
#
# ![Linear-Regression_figure.png](attachment:Linear-Regression_figure.png)

# %% [markdown]
# ## Outlines
#
#
# *   Problem
# *   Write python code
# *   Import libraries
# *   Load data from csv file
# *   Plot scatter
# *   Linear Regression Model
# *   Prediction
# *   Calculate slope (m) & Intercept (b)
# *   Quiz
# *   How does linear equation look?
# *   Excercise 1
# *   Excercise 2

# %% [markdown]
# # Problem
# Based on the table shown below, what is the price of homes whose area are **3300** square feet & **5000** square feet?

# %% [markdown]
# ![Problem1.png](attachment:Problem1.png)

# %% [markdown]
# </hr>

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# ![1_model.png](attachment:1_model.png)

# %% [markdown]
# ![3.png](attachment:3.png)

# %% [markdown]
# ![4.png](attachment:4.png)

# %% [markdown]
# <hr>

# %% [markdown]
# ![variables.png](attachment:variables.png)

# %% [markdown]
# <hr/>
# <div class="alert alert-success alertsuccess" style="margin-top: 20px">
# [Tip]: To execute the Python code in the code cell below, click on the cell to select it and press <kbd>Shift</kbd> + <kbd>Enter</kbd>.
# </div>
# <hr/>

# %% [markdown]
# ## Write Python Code

# %% [markdown]
# <hr>

# %% [markdown]
# ## import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %% [markdown]
# ## load data from csv file

# %%
# load data from csv file
# write the address of your folder where you save csv file
df = pd.read_csv('D:/Data_Science/My Github/Machine-Learning-with-Python/Linear_Regression/Example/homeprice.csv')
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %% [markdown]
# ## Plot scatter

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price,color='red',marker='+')

# %% [markdown]
# ## Linear Regression Model

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %% [markdown]
# ## Prediction

# %%
reg.predict([[3300]])
# Out:
# array([628715.75342466])

# %% [markdown]
# ## Calculate Slope (m) & Intercept (b)

# %%
print('m= %s , b= %s ' % (reg.coef_,reg.intercept_))
# Out:
# m= [135.78767123] , b= 180616.43835616432

# %%
m = reg.coef_
b = reg.intercept_
x=3300
y=m*x+b
y
# Out:
# array([628715.75342466])

# %% [markdown]
# ## Quiz: Predict the price of 5000 feet square?

# %%
# Write your code

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# reg.predict([[5000]])
# ```
#
# </details>

# %% [markdown]
# ## How does Linear Equation Look?

# %%
# %matplotlib inline
plt.xlabel('area', fontsize=20)
plt.ylabel('price', fontsize=20)
plt.scatter(df.area,df.price,color='red',marker='+')
plt.plot(df.area,reg.predict(df[['area']]),color='blue')

# %% [markdown]
# # Excercise 1:
# ## A list of area is given in a csv file:
# 1. Load the csv file excercise.csv from your directory.
# 2. Predict the prices based on Linear Regression model.
# 3. Assign predictions to your data and print your new data.
# 4. write your new dataframe to a new csv file with a name prediction.csv.
# 5. Omit index from new data and write it in a new csv file named prediction1.csv

# %% [markdown]
# <details><summary>Click here for the solution part 1</summary>
#
# ```python
# # load csv file
# d = pd.read_csv('D:/Data_Science/My Github/Machine-Learning-with-Python/Linear_Regression/Excercise_1/excercise_1.csv')
# d
# ```
#
# </details>

# %% [markdown]
# <details><summary>Click here for the solution part 2</summary>
#
# ```python
# # predict the prices
# p = reg.predict(d)
# ```
#
# </details>

# %% [markdown]
# <details><summary>Click here for the solution part 3</summary>
#
# ```python
# # assign predictions to data and print a new data
# d['prices'] = p
# d
# ```
#
# </details>

# %% [markdown]
# <details><summary>Click here for the solution part 4</summary>
#
# ```python
# # write to a new csv file with a new column
# # tip: you shouldn't have prediction.csv in your directory
# d.to_csv('D:/Data_Science/My Github/Machine-Learning-with-Python/Linear_Regression/Excercise_1/prediction.csv')
# ```
#
# </details>

# %% [markdown]
# <details><summary>Click here for the solution part 5</summary>
#
# ```python
# # wrie in a new csv file named prediction1.csv
# # omit index
# d.to_csv('D:/Data_Science/My Github/Machine-Learning-with-Python/Linear_Regression/Excercise_1/prediction1.csv',index=False)
#
# ```
#
# </details>

# %% [markdown]
# # Excercise 2:
# ## <div style="text-align: left"> A Canada's income is given in the folder from year  1970-2016. Your job is to predict the Canada's income in 2021? </div>

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df1 = pd.read_csv('D:/Data_Science/My Github/Machine-Learning-with-Python/Linear_Regression/Excercise_2/canada_per_capita_income.csv')
# reg1 = linear_model.LinearRegression()
# reg1.fit(df1[['year']],df1.per_capita_income)
# reg1.predict([[2021]])
# ```
#
# </details>

# %% [markdown]
# ## Author
# <div style="text-align: left"> Ehsan Zia </div>
